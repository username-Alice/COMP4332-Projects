# %%
import networkx as nx
import numpy as np
import os
import time
import pandas as pd
import matplotlib.pyplot as plt
from itertools import chain
from collections import defaultdict
from gensim.models import Word2Vec
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### Data Loader

# %% [markdown]
# We need to load networks into memory. Usually networks are organized as pairs of nodes. And sometimes different edges have different weights. Hence, we use networkx.DiGraph to store such structure information and attributes.

# %%
def load_data(file_name):
    """
    read edges from an edge file
    """
    edges = list()
    df = pd.read_csv(file_name)
    for idx, row in df.iterrows():
        user_id, friends = row["user_id"], eval(row["friends"])
        for friend in friends:
            # add each friend relation as an edge
            edges.append((user_id, friend))
    edges = sorted(edges)

    return edges

def load_test_data(file_name):
    """
    read edges from an edge file
    """
    edges = list()
    scores = list()
    df = pd.read_csv(file_name)
    for idx, row in df.iterrows():
        edges.append((row["src"], row["dst"]))
        scores.append(row["score"])
    #edges = sorted(edges)

    return edges,scores

def generate_false_edges(true_edges, num_false_edges=5):
    """
    generate false edges given true edges
    """
    nodes = list(set(chain.from_iterable(true_edges)))
    N = len(nodes)
    true_edges = set(true_edges)
    print(N, len(true_edges))
    false_edges = set()

    while len(false_edges) < num_false_edges:
        # randomly sample two different nodes and check whether the pair exisit or not
        src, dst = nodes[int(np.random.rand() * N)], nodes[int(np.random.rand() * N)]
        if src != dst and (src, dst) not in true_edges and (src, dst) not in false_edges:
            false_edges.add((src, dst))
    false_edges = sorted(false_edges)

    return false_edges

def construct_graph_from_edges(edges):
    """
    generate a directed graph object given true edges
    DiGraph documentation: https://networkx.github.io/documentation/stable/reference/classes/digraph.html
    """
    # convert a list of edges {(u, v)} to a list of edges with weights {(u, v, w)}
    edge_weight = defaultdict(float)
    for e in edges:
        edge_weight[e] += 1.0
    weighed_edge_list = list()
    for e in sorted(edge_weight.keys()):
        weighed_edge_list.append((e[0], e[1], edge_weight[e]))

    graph = nx.DiGraph()
    graph.add_weighted_edges_from(weighed_edge_list)

    print("number of nodes:", graph.number_of_nodes())
    print("number of edges:", graph.number_of_edges())

    return graph

# %% [markdown]
# ### Random Walk Generator

# %% [markdown]
# Random walk generators or random walkers yield random walks that contain both local and higher-order neighborhood information. However, naive non-uniform sampling is very slow, which requires O(n) time complexity. Here alias sampling can reduce the time complexity to O(1) with O(n) space. If you are interested, please see the following blog.

# %%
def alias_setup(probs):
    """
    compute utility lists for non-uniform sampling from discrete distributions.
    details: https://lips.cs.princeton.edu/the-alias-method-efficient-sampling-with-many-discrete-outcomes/
    """
    K = len(probs)
    q = np.zeros(K)
    J = np.zeros(K, dtype=int)

    smaller = list()
    larger = list()
    for kk, prob in enumerate(probs):
        q[kk] = K * prob
        if q[kk] < 1.0:
            smaller.append(kk)
        else:
            larger.append(kk)

    while len(smaller) > 0 and len(larger) > 0:
        small = smaller.pop()
        large = larger.pop()

        J[small] = large
        q[large] = q[large] + q[small] - 1.0
        if q[large] < 1.0:
            smaller.append(large)
        else:
            larger.append(large)

    return J, q

def get_alias_node(graph, node):
    """
    get the alias node setup lists for a given node.
    """
    # get the unnormalized probabilities with the first-order information
    unnormalized_probs = list()
    for nbr in graph.neighbors(node):
        unnormalized_probs.append(graph[node][nbr]["weight"])
    unnormalized_probs = np.array(unnormalized_probs)
    if len(unnormalized_probs) > 0:
        normalized_probs = unnormalized_probs / unnormalized_probs.sum()
    else:
        normalized_probs = unnormalized_probs

    return alias_setup(normalized_probs)

def get_alias_edge(graph, src, dst, p=1, q=1):
    """
    get the alias edge setup lists for a given edge.
    """
    # get the unnormalized probabilities with the second-order information
    unnormalized_probs = list()
    for dst_nbr in graph.neighbors(dst):
        if dst_nbr == src: # distance is 0
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"]/p)
        elif graph.has_edge(dst_nbr, src): # distance is 1
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"])
        else: # distance is 2
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"]/q)
    unnormalized_probs = np.array(unnormalized_probs)
    if len(unnormalized_probs) > 0:
        normalized_probs = unnormalized_probs / unnormalized_probs.sum()
    else:
        normalized_probs = unnormalized_probs

    return alias_setup(normalized_probs)

def preprocess_transition_probs(graph, p=1, q=1):
    """
    preprocess transition probabilities for guiding the random walks.
    """
    alias_nodes = dict()
    for node in graph.nodes():
        alias_nodes[node] = get_alias_node(graph, node)

    alias_edges = dict()
    for edge in graph.edges():
        alias_edges[edge] = get_alias_edge(graph, edge[0], edge[1], p=p, q=q)

    return alias_nodes, alias_edges

# %% [markdown]
# The difference between DeepWalk and node2vec is how to generate random walks. The former only consider the first-order information while the latter also involves the second-order information.

# %%
def alias_draw(J, q):
    """
    draw sample from a non-uniform discrete distribution using alias sampling.
    """
    K = len(J)

    kk = int(np.floor(np.random.rand() * K))
    if np.random.rand() < q[kk]:
        return kk
    else:
        return J[kk]


# helper function to generate the long random walk as desired
def fallback(walk, fetch_last_num=1):
    if len(walk) > fetch_last_num:
        walk.pop()
        fetched = []
        for i in range(fetch_last_num):
            fetched.append(walk[-1-i])
        return walk, fetched
    else:
        return [], [None for _ in range(fetch_last_num)]

def generate_first_order_random_walk(graph, alias_nodes,
                                     walk_length=10, start_node=None, verbose=False, max_trails=10):
    """
    simulate a random walk starting from start node and considering the first order information.
    max_trials: set the max trials to be one for standard random walk. Larger max_trails will make the generated biased.
    """
    if start_node == None:
        start_node = np.random.choice(graph.nodes())
    walk = [start_node]
    cur = start_node
    num_tried = 0

    ########## begin ##########
    while len(walk) < walk_length:
        cur_nbrs = list(graph.neighbors(cur))
        if len(cur_nbrs) > 0: # if we can sample next nodes
            # sample the next node based on alias_nodes
            cur = cur_nbrs[alias_draw(*alias_nodes[cur])]
            walk.append(cur)
        else: # if we can't do that
            num_tried += 1
            if num_tried >= max_trails:
                break

            walk, fetched = fallback(walk, fetch_last_num=1)
            cur = fetched[0]
            if len(walk) == 0: # if falls back to the empty walk
                start_node = np.random.choice(graph.nodes())
                walk = [start_node]
                cur = start_node
    ########## end ##########

    if verbose:
        print(f'walk of lenght {len(walk)} generated with {num_tried} trails')
    return walk

def generate_second_order_random_walk(graph, alias_nodes, alias_edges,
                                      walk_length=10, start_node=None, verbose=False, max_trails=10):
    """
    simulate a random walk starting from start node and considering the second order information.
    """
    if start_node == None:
        start_node = np.random.choice(graph.nodes())
    walk = [start_node]

    prev = None
    cur = start_node
    num_tried = 0

    ########## begin ##########
    while len(walk) < walk_length:
        cur_nbrs = list(graph.neighbors(cur))
        if len(cur_nbrs) > 0:
            if prev is None:
                # sample the next node based on alias_nodes
                prev, cur = cur, cur_nbrs[alias_draw(*alias_nodes[cur])]
            else:
                # sample the next node based on alias_edges
                prev, cur = cur, cur_nbrs[alias_draw(*alias_edges[(prev, cur)])]
            walk.append(cur)
        else:
            num_tried += 1
            if num_tried >= max_trails:
                break
            walk, (cur, prev) = fallback(walk, fetch_last_num=2)
            if len(walk) == 0:
                start_node = np.random.choice(graph.nodes())
                walk = [start_node]
                cur = start_node
                prev = None
    ########## end ##########
    if verbose:
        print(f'walk of lenght {len(walk)} generated with {num_tried} trails')
    return walk

# %% [markdown]
# ### Network Embedding Algorithms

# %%
def build_deepwalk(graph, alias_nodes, node_dim=10, num_walks=10, walk_length=10):
    """
    build a deepwalk model
    """
    print("building a DeepWalk model...", end="\t")
    st = time.time()
    np.random.seed(0)
    nodes = list(graph.nodes())
    walks = list()
    # generate random walks
    for walk_iter in range(num_walks):
        np.random.shuffle(nodes)
        for node in nodes:
            walks.append(generate_first_order_random_walk(
                graph, alias_nodes, walk_length=walk_length, start_node=node))

    walk_lens = [len(w) for w in walks]
    if len(walk_lens) > 0:
        avg_walk_len = sum(walk_lens) / len(walk_lens)
    else:
        avg_walk_len = 0.0
    print("number of walks: %d\taverage walk length: %.4f" % (len(walks), avg_walk_len), end="\t")

    # train a skip-gram model for these walks
    model = Word2Vec(walks, vector_size=node_dim, window=3, min_count=0, sg=1, workers=os.cpu_count(), epochs=10)
    print("training time: %.4f" % (time.time()-st))

    return model

def build_node2vec(graph, alias_nodes, alias_edges, node_dim=10, num_walks=10, walk_length=10,num_window = 3, num_epoch = 10):
    """
    build a node2vec model
    """
    print("building a node2vec model...", end="\t")
    st = time.time()
    np.random.seed(0)
    nodes = list(graph.nodes())
    walks = list()
    # generate random walks
    for walk_iter in range(num_walks):
        np.random.shuffle(nodes)
        for node in nodes:
            walks.append(generate_second_order_random_walk(
                graph, alias_nodes, alias_edges, walk_length=walk_length, start_node=node))

    walk_lens = [len(w) for w in walks]
    if len(walk_lens) > 0:
        avg_walk_len = sum(walk_lens) / len(walk_lens)
    else:
        avg_walk_len = 0.0
    print("number of walks: %d\taverage walk length: %.4f" % (len(walks), avg_walk_len), end="\t")

    # train a skip-gram model for these walks
    model = Word2Vec(walks, vector_size=node_dim, window=num_window, min_count=0, sg=1, workers=os.cpu_count(), epochs=num_epoch)
    print("training time: %.4f" % (time.time()-st))

    return model

# %% [markdown]
# ### Scorer

# %%
def get_cosine_sim(model, u, v):
    """
    get the cosine similarity between two nodes
    """
    try:
        u = model.wv[u]
        v = model.wv[v]
        return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
    except:
        return 0.5

def get_auc_score(model, true_edges, false_edges):
    """
    get the auc score
    """
    y_true = [1] * len(true_edges) + [0] * len(false_edges)

    y_score = list()
    for e in true_edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))
    for e in false_edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))

    return roc_auc_score(y_true, y_score)

def get_auc_score_test(model, edges,scores):
    """
    get the auc score
    """
    y_true = scores

    y_score = list()
    for e in edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))

    return roc_auc_score(y_true, y_score)


def write_pred(file_name, edges, scores):
    df = pd.DataFrame()
    df["src"] = [e[0] for e in edges]
    df["dst"] = [e[1] for e in edges]
    df["score"] = scores
    df.to_csv(file_name, index=False)





def write_valid_ans(file_name, edges, scores):
    df = pd.DataFrame()
    df["src"] = [e[0] for e in edges]
    df["dst"] = [e[1] for e in edges]
    df["score"] = scores
    df.to_csv(file_name, index=False)

# %% [markdown]
# ### Try them over a Real-life Network

# %% [markdown]
# Firstly, we need to load edges into memory and use the networkx.DiGraph structure to store the graph.

# %%
from google.colab import drive
drive.mount('/content/drive')
data_path = "/content/drive/MyDrive/Colab Notebooks/comp4332/Project2/data"
# !rm -f data
# !ln -s "/content/drive/MyDrive/Colab Notebooks/comp4332/Project2/data" data
# Out:
# Mounted at /content/drive

# %%
train_file = "data/train.csv"
valid_file = "data/valid.csv"
test_file = "data/test.csv"

np.random.seed(2024)
train_edges = load_data(train_file)
graph = construct_graph_from_edges(train_edges)
#nx.draw(graph)
valid_edges = load_data(valid_file)
false_edges = generate_false_edges(train_edges + valid_edges, 40000 - len(valid_edges))
test_edges,test_scores = load_test_data(test_file)
# Out:
# number of nodes: 72795
# number of edges: 100000
# 85407 120000

# %% [markdown]
# After that, we can use preprocess transition probabilities with the help of alias sampling.

# %%
#alias_nodes, alias_edges = preprocess_transition_probs(graph, p=1, q=1)

# %% [markdown]
# We can use random walk generators to generate random walks.

# %% [markdown]
# Let's try to generate a first-order random walk and a second-order random walk.

# %%
#generate_first_order_random_walk(graph, alias_nodes=alias_nodes,
#                                 start_node="B01I2MU2JQ", walk_length=10)

# %%
#generate_second_order_random_walk(graph, alias_nodes=alias_nodes, alias_edges=alias_edges,
#                                  start_node="B01I2MU2JQ", walk_length=10)

# %% [markdown]
# And we can build a DeepWalk model and a node2vec model. Here we set p=q=0.5 so that the walker will not go very far away from the start node.

# %%
#model_walk = build_deepwalk(graph, alias_nodes, node_dim=20, num_walks=10, walk_length=10)

# %%
#model_work2vec = build_node2vec(graph, alias_nodes, alias_edges, node_dim=20, num_walks=10, walk_length=10)

# %%
#model = model_walk

# %% [markdown]
# Let's see the node embeddings of three nodes, and cosine similarities of two edges.

# %%
'''print("node embedding (\"AF7QSFSONY6JAFLVH3PFOLFQWETA\"):",
      model.wv["AF7QSFSONY6JAFLVH3PFOLFQWETA"])
print("node embedding (\"B01I2MU2JQ\"):",
      model.wv["B01I2MU2JQ"])
print("node embedding (\"AFKMKEPHZWDWJXRRR36T5RC7625Q\"):",
      model.wv.vectors[model.wv.index_to_key.index("AFKMKEPHZWDWJXRRR36T5RC7625Q")])
print("true edge (\"AF7QSFSONY6JAFLVH3PFOLFQWETA\", \"B01I2MU2JQ\"):",
      get_cosine_sim(model, "AF7QSFSONY6JAFLVH3PFOLFQWETA", "B01I2MU2JQ"))
print("false edge (\"AF7QSFSONY6JAFLVH3PFOLFQWETA\", \"AFKMKEPHZWDWJXRRR36T5RC7625Q\"):",
      get_cosine_sim(model, "N6ZTMIue-2b30CJv2tyPGg", "MmlJSLDg-IFaeXb5wdJbgg"))'''
# Out:
# 'print("node embedding ("AF7QSFSONY6JAFLVH3PFOLFQWETA"):",\n      model.wv["AF7QSFSONY6JAFLVH3PFOLFQWETA"])\nprint("node embedding ("B01I2MU2JQ"):",\n      model.wv["B01I2MU2JQ"])\nprint("node embedding ("AFKMKEPHZWDWJXRRR36T5RC7625Q"):",\n      model.wv.vectors[model.wv.index_to_key.index("AFKMKEPHZWDWJXRRR36T5RC7625Q")])\nprint("true edge ("AF7QSFSONY6JAFLVH3PFOLFQWETA", "B01I2MU2JQ"):",\n      get_cosine_sim(model, "AF7QSFSONY6JAFLVH3PFOLFQWETA", "B01I2MU2JQ"))\nprint("false edge ("AF7QSFSONY6JAFLVH3PFOLFQWETA", "AFKMKEPHZWDWJXRRR36T5RC7625Q"):",\n      get_cosine_sim(model, "N6ZTMIue-2b30CJv2tyPGg", "MmlJSLDg-IFaeXb5wdJbgg"))'

# %% [markdown]
# # Link Prediction

# %% [markdown]
# We can train the model with different parameters and test the model on the validation set. Please show your parameter search process and analysis in your code, and visualization tools (Heatmap, etc.) are recommended to make your analysis clear.

# %%
# np.random.seed(0)

# node_dim = np.array([64,128,256,512]) # only 64 is finished, when node_dim = 128, numwalk , walk length = 25, accuracy = 75.19
# num_walks = np.arange(25,101,25)
# walk_length = np.arange(25,101,25)
# best_dim = -1
# best_walk = -1
# best_length = -1
# best_score = -1
# deepwalk_auc_scores = dict()
# """print("node dim: %d,\tnum_walks: %d,\twalk_length: %d" % (node_dim, num_walks, walk_length), end="\t")"""
# for dim in node_dim:
#   for walk in num_walks:
#     for length in walk_length:
#       model = build_deepwalk(graph, alias_nodes,
#               node_dim = dim, num_walks= walk, walk_length = length)
#       deepwalk_auc_scores[(dim, walk, length,'valid')] = get_auc_score(model, valid_edges, false_edges)
#       print("valid auc: %.4f" % (deepwalk_auc_scores[(dim, walk, length,'valid')]))

# %%
node_dim = [8,16,32,64,128,256]#np.array([256])
num_walks = [1,2,3,4,5]#np.arange(5,11,5)
walk_length = [1,2,3,4,5]#np.arange(5,11,5)
num_window = np.arange(5,21,5)
num_epochs = np.arange(5,21,5)
P = [2.4]#np.arange(0.2,4.2,0.2)
Q = [0.4]#np.arange(0.2,4.2,0.2)

# %%
np.random.seed(0)
best_valid_accuracy = 0
counter = 0
node2vec_auc_scores = dict()
for numWindow in num_window:
    for numEpoch in num_epochs:
        for dim in node_dim:
            for walk in num_walks:
                for length in walk_length:
                    for p in P:
                        for q in Q:
                            print("node dim: %d,\tnum_walks: %d,\twalk_length: %d,\tp: %.2f,\tq: %.2f,\tw: %.2f,\te: %.2f" % (
                                dim, walk, length, p, q,numWindow,numEpoch), end="\t")
                            alias_nodes, alias_edges = preprocess_transition_probs(graph, p=p, q=q)
                            model = build_node2vec(graph, alias_nodes, alias_edges,
                                                    node_dim=dim, num_walks=walk, walk_length=length,num_window=numWindow,num_epoch=numEpoch)
                            node2vec_auc_scores[(dim, walk, length, p, q,numWindow,numEpoch,'valid')] = get_auc_score(model, valid_edges, false_edges)
                            print("valid auc: %.4f" % (node2vec_auc_scores[(dim, walk, length, p, q,numWindow,numEpoch,'valid')]))
# Out:
# node dim: 8,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 4.3559
# valid auc: 0.7937
# node dim: 8,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 4.9575
# valid auc: 0.7946
# node dim: 8,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 6.0084
# valid auc: 0.7939
# node dim: 8,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 6.5249
# valid auc: 0.7936
# node dim: 8,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 6.8983
# valid auc: 0.7927
# node dim: 8,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 8.2625
# valid auc: 0.7937
# node dim: 8,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 6.6040
# valid auc: 0.7947
# node dim: 8,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 8.5998
# valid auc: 0.7997
# node dim: 8,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 9.2114
# valid auc: 0.7913
# node dim: 8,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 14.1688
# valid auc: 0.7365
# node dim: 8,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 5.5380
# valid auc: 0.7937
# node dim: 8,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 7.9092
# valid auc: 0.7966
# node dim: 8,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 12.2271
# valid auc: 0.7946
# node dim: 8,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 11.2322
# valid auc: 0.5771
# node dim: 8,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 12.9057
# valid auc: 0.1753
# node dim: 8,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 6.5329
# valid auc: 0.7937
# node dim: 8,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 3.4391
# valid auc: 0.7969
# node dim: 8,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 5.4099
# valid auc: 0.7921
# node dim: 8,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 5.8745
# valid auc: 0.2197
# node dim: 8,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 7.4187
# valid auc: 0.1913
# node dim: 8,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 2.4572
# valid auc: 0.7937
# node dim: 8,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 4.6582
# valid auc: 0.7957
# node dim: 8,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 5.6291
# valid auc: 0.7888
# node dim: 8,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 7.9172
# valid auc: 0.1717
# node dim: 8,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 9.5827
# valid auc: 0.3908
# node dim: 16,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.2631
# valid auc: 0.8409
# node dim: 16,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 2.1580
# valid auc: 0.8419
# node dim: 16,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.9036
# valid auc: 0.8418
# node dim: 16,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 3.3040
# valid auc: 0.8420
# node dim: 16,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 2.6984
# valid auc: 0.8412
# node dim: 16,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 3.1739
# valid auc: 0.8409
# node dim: 16,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 2.3341
# valid auc: 0.8427
# node dim: 16,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 9.6497
# valid auc: 0.8414
# node dim: 16,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 3.7584
# valid auc: 0.8384
# node dim: 16,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 5.2848
# valid auc: 0.6753
# node dim: 16,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 1.9758
# valid auc: 0.8409
# node dim: 16,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 6.6881
# valid auc: 0.8423
# node dim: 16,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 4.0587
# valid auc: 0.8409
# node dim: 16,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 10.2113
# valid auc: 0.4248
# node dim: 16,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 6.5870
# valid auc: 0.1552
# node dim: 16,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 5.1136
# valid auc: 0.8409
# node dim: 16,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.7389
# valid auc: 0.8415
# node dim: 16,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 5.3008
# valid auc: 0.8395
# node dim: 16,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 15.6812
# valid auc: 0.1768
# node dim: 16,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 9.7028
# valid auc: 0.1594
# node dim: 16,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 2.7945
# valid auc: 0.8409
# node dim: 16,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 7.5749
# valid auc: 0.8398
# node dim: 16,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 9.9330
# valid auc: 0.8376
# node dim: 16,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 8.2505
# valid auc: 0.1558
# node dim: 16,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 17.2997
# valid auc: 0.3154
# node dim: 32,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.2511
# valid auc: 0.8555
# node dim: 32,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 1.6585
# valid auc: 0.8557
# node dim: 32,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 4.4090
# valid auc: 0.8550
# node dim: 32,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 5.0526
# valid auc: 0.8553
# node dim: 32,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 4.1047
# valid auc: 0.8554
# node dim: 32,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 1.6485
# valid auc: 0.8555
# node dim: 32,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 2.9617
# valid auc: 0.8554
# node dim: 32,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 6.5149
# valid auc: 0.8551
# node dim: 32,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 8.4386
# valid auc: 0.8551
# node dim: 32,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 7.2045
# valid auc: 0.5835
# node dim: 32,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 2.8346
# valid auc: 0.8555
# node dim: 32,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 4.1367
# valid auc: 0.8554
# node dim: 32,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 4.0226
# valid auc: 0.8548
# node dim: 32,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 10.4405
# valid auc: 0.3310
# node dim: 32,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 7.8841
# valid auc: 0.1511
# node dim: 32,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 2.3671
# valid auc: 0.8555
# node dim: 32,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 4.3329
# valid auc: 0.8555
# node dim: 32,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 10.6987
# valid auc: 0.8551
# node dim: 32,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 10.9139
# valid auc: 0.1710
# node dim: 32,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 7.4317
# valid auc: 0.1499
# node dim: 32,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 8.5337
# valid auc: 0.8555
# node dim: 32,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 9.3435
# valid auc: 0.8545
# node dim: 32,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 8.3556
# valid auc: 0.8546
# node dim: 32,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 7.7630
# valid auc: 0.1498
# node dim: 32,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 23.4172
# valid auc: 0.2031
# node dim: 64,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 2.4873
# valid auc: 0.8561
# node dim: 64,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 2.9096
# valid auc: 0.8558
# node dim: 64,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.1019
# valid auc: 0.8562
# node dim: 64,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 3.2650
# valid auc: 0.8560
# node dim: 64,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 3.6453
# valid auc: 0.8557
# node dim: 64,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 2.1990
# valid auc: 0.8561
# node dim: 64,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 2.4222
# valid auc: 0.8561
# node dim: 64,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 4.2829
# valid auc: 0.8561
# node dim: 64,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 6.5509
# valid auc: 0.8571
# node dim: 64,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 7.4007
# valid auc: 0.6623
# node dim: 64,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 1.9998
# valid auc: 0.8561
# node dim: 64,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 2.9867
# valid auc: 0.8562
# node dim: 64,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 11.0700
# valid auc: 0.8562
# node dim: 64,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 9.5957
# valid auc: 0.3226
# node dim: 64,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 7.0073
# valid auc: 0.1533
# node dim: 64,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 2.8346
# valid auc: 0.8561
# node dim: 64,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 3.7314
# valid auc: 0.8567
# node dim: 64,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 12.1500
# valid auc: 0.8565
# node dim: 64,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 15.0096
# valid auc: 0.1815
# node dim: 64,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 7.8271
# valid auc: 0.1466
# node dim: 64,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 3.2379
# valid auc: 0.8561
# node dim: 64,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 4.9195
# valid auc: 0.8561
# node dim: 64,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 15.1017
# valid auc: 0.8569
# node dim: 64,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 18.1204
# valid auc: 0.1486
# node dim: 64,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 9.0044
# valid auc: 0.1694
# node dim: 128,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.1868
# valid auc: 0.8566
# node dim: 128,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 1.6285
# valid auc: 0.8565
# node dim: 128,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.0188
# valid auc: 0.8559
# node dim: 128,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 2.9657
# valid auc: 0.8563
# node dim: 128,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 2.7636
# valid auc: 0.8563
# node dim: 128,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 1.5724
# valid auc: 0.8566
# node dim: 128,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 2.2741
# valid auc: 0.8563
# node dim: 128,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 3.1262
# valid auc: 0.8564
# node dim: 128,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 4.3090
# valid auc: 0.8575
# node dim: 128,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 4.5471
# valid auc: 0.5295
# node dim: 128,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 1.8241
# valid auc: 0.8566
# node dim: 128,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 3.0928
# valid auc: 0.8565
# node dim: 128,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 4.7703
# valid auc: 0.8564
# node dim: 128,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 5.4740
# valid auc: 0.2916
# node dim: 128,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 7.2966
# valid auc: 0.1549
# node dim: 128,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 2.3031
# valid auc: 0.8566
# node dim: 128,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 3.8525
# valid auc: 0.8562
# node dim: 128,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 6.0445
# valid auc: 0.8567
# node dim: 128,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 6.9933
# valid auc: 0.1807
# node dim: 128,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 9.4386
# valid auc: 0.1453
# node dim: 128,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 2.6434
# valid auc: 0.8566
# node dim: 128,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 5.1196
# valid auc: 0.8560
# node dim: 128,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 7.2276
# valid auc: 0.8576
# node dim: 128,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 8.3826
# valid auc: 0.1481
# node dim: 128,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 11.3338
# valid auc: 0.1585
# node dim: 256,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.3652
# valid auc: 0.8562
# node dim: 256,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 2.0388
# valid auc: 0.8563
# node dim: 256,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.5303
# valid auc: 0.8560
# node dim: 256,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 3.1513
# valid auc: 0.8561
# node dim: 256,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 3.9085
# valid auc: 0.8565
# node dim: 256,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 1.6145
# valid auc: 0.8562
# node dim: 256,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 2.7495
# valid auc: 0.8564
# node dim: 256,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 4.6592
# valid auc: 0.8566
# node dim: 256,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 5.0556
# valid auc: 0.8571
# node dim: 256,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 6.1526
# valid auc: 0.4540
# node dim: 256,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 2.6254
# valid auc: 0.8562
# node dim: 256,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 3.4802
# valid auc: 0.8558
# node dim: 256,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 5.2758
# valid auc: 0.8562
# node dim: 256,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 7.3256
# valid auc: 0.2743
# node dim: 256,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 8.6358
# valid auc: 0.1562
# node dim: 256,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 2.1570
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 4.8684
# valid auc: 0.8563
# node dim: 256,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 6.3488
# valid auc: 0.8567
# node dim: 256,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 8.9352
# valid auc: 0.1876
# node dim: 256,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 10.5314
# valid auc: 0.1444
# node dim: 256,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 3.1106
# valid auc: 0.8562
# node dim: 256,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 5.0196
# valid auc: 0.8564
# node dim: 256,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 8.2925
# valid auc: 0.8577
# node dim: 256,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 9.9981
# valid auc: 0.1478
# node dim: 256,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 5.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 13.5112
# valid auc: 0.1533
# node dim: 8,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.4443
# valid auc: 0.7937
# node dim: 8,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 1.9167
# valid auc: 0.7947
# node dim: 8,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.3371
# valid auc: 0.7943
# node dim: 8,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 2.7838
# valid auc: 0.7898
# node dim: 8,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 3.1038
# valid auc: 0.7258
# node dim: 8,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 2.1035
# valid auc: 0.7937
# node dim: 8,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 3.4072
# valid auc: 0.7939
# node dim: 8,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 3.7597
# valid auc: 0.7974
# node dim: 8,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 4.3676
# valid auc: 0.2176
# node dim: 8,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 5.2349
# valid auc: 0.1908
# node dim: 8,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 3.1887
# valid auc: 0.7937
# node dim: 8,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 3.9246
# valid auc: 0.7970
# node dim: 8,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 4.9675
# valid auc: 0.7522
# node dim: 8,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 6.6971
# valid auc: 0.2113
# node dim: 8,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 7.1735
# valid auc: 0.5311
# node dim: 8,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 3.9127
# valid auc: 0.7937
# node dim: 8,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 4.7315
# valid auc: 0.7973
# node dim: 8,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 6.3790
# valid auc: 0.2725
# node dim: 8,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 8.2595
# valid auc: 0.4583
# node dim: 8,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 9.2426
# valid auc: 0.5770
# node dim: 8,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 4.3424
# valid auc: 0.7937
# node dim: 8,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 5.8235
# valid auc: 0.7947
# node dim: 8,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 8.2145
# valid auc: 0.1595
# node dim: 8,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 10.0911
# valid auc: 0.5487
# node dim: 8,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 11.0732
# valid auc: 0.5786
# node dim: 16,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.4602
# valid auc: 0.8409
# node dim: 16,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 1.9001
# valid auc: 0.8420
# node dim: 16,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.4352
# valid auc: 0.8414
# node dim: 16,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 2.7682
# valid auc: 0.8390
# node dim: 16,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 3.9576
# valid auc: 0.6930
# node dim: 16,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 2.0649
# valid auc: 0.8409
# node dim: 16,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 3.1659
# valid auc: 0.8425
# node dim: 16,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 3.9025
# valid auc: 0.8401
# node dim: 16,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 5.4249
# valid auc: 0.1789
# node dim: 16,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 5.6191
# valid auc: 0.1610
# node dim: 16,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 2.8266
# valid auc: 0.8409
# node dim: 16,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 4.0517
# valid auc: 0.8427
# node dim: 16,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 6.0275
# valid auc: 0.7842
# node dim: 16,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 6.5019
# valid auc: 0.1702
# node dim: 16,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 7.7600
# valid auc: 0.5631
# node dim: 16,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 3.8690
# valid auc: 0.8409
# node dim: 16,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 5.0266
# valid auc: 0.8411
# node dim: 16,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 7.2446
# valid auc: 0.2111
# node dim: 16,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 8.2925
# valid auc: 0.4273
# node dim: 16,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 10.7227
# valid auc: 0.6406
# node dim: 16,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 4.0387
# valid auc: 0.8409
# node dim: 16,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 6.6200
# valid auc: 0.8372
# node dim: 16,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 9.0363
# valid auc: 0.1487
# node dim: 16,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 10.2933
# valid auc: 0.6108
# node dim: 16,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 12.1750
# valid auc: 0.6520
# node dim: 32,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.4504
# valid auc: 0.8555
# node dim: 32,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 1.9688
# valid auc: 0.8557
# node dim: 32,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.4213
# valid auc: 0.8549
# node dim: 32,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 2.8717
# valid auc: 0.8547
# node dim: 32,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 3.2009
# valid auc: 0.5812
# node dim: 32,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 2.1071
# valid auc: 0.8555
# node dim: 32,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 2.9357
# valid auc: 0.8553
# node dim: 32,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 4.4170
# valid auc: 0.8546
# node dim: 32,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 4.5311
# valid auc: 0.1728
# node dim: 32,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 5.4379
# valid auc: 0.1516
# node dim: 32,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 2.6603
# valid auc: 0.8555
# node dim: 32,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 4.5583
# valid auc: 0.8553
# node dim: 32,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 5.1218
# valid auc: 0.8240
# node dim: 32,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 6.9444
# valid auc: 0.1566
# node dim: 32,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 7.4078
# valid auc: 0.5532
# node dim: 32,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 3.3691
# valid auc: 0.8555
# node dim: 32,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 5.4302
# valid auc: 0.8559
# node dim: 32,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 6.5872
# valid auc: 0.2009
# node dim: 32,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 8.5718
# valid auc: 0.3095
# node dim: 32,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 9.6620
# valid auc: 0.7170
# node dim: 32,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 4.3783
# valid auc: 0.8555
# node dim: 32,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 5.9586
# valid auc: 0.8547
# node dim: 32,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 8.4159
# valid auc: 0.1466
# node dim: 32,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 9.8279
# valid auc: 0.6496
# node dim: 32,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 12.1732
# valid auc: 0.7354
# node dim: 64,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 1.6165
# valid auc: 0.8561
# node dim: 64,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 1.9898
# valid auc: 0.8558
# node dim: 64,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 2.6984
# valid auc: 0.8562
# node dim: 64,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 3.0257
# valid auc: 0.8567
# node dim: 64,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 3.5702
# valid auc: 0.5990
# node dim: 64,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 2.7339
# valid auc: 0.8561
# node dim: 64,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 3.1779
# valid auc: 0.8561
# node dim: 64,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 4.0527
# valid auc: 0.8563
# node dim: 64,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 5.1727
# valid auc: 0.1819
# node dim: 64,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 7.5709
# valid auc: 0.1462
# node dim: 64,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 4.6622
# valid auc: 0.8561
# node dim: 64,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 4.4630
# valid auc: 0.8562
# node dim: 64,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 10.2363
# valid auc: 0.8493
# node dim: 64,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 5.00,	e: 10.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 12.4713
# valid auc: 0.1506
# ...
# valid auc: 0.2692
# node dim: 32,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 13.9449
# valid auc: 0.6990
# node dim: 32,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 16.3608
# valid auc: 0.7346
# node dim: 32,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 19.5967
# valid auc: 0.7434
# node dim: 64,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 2.0814
# valid auc: 0.8561
# node dim: 64,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 2.9517
# valid auc: 0.8558
# node dim: 64,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 3.9237
# valid auc: 0.8564
# node dim: 64,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 4.6852
# valid auc: 0.1580
# node dim: 64,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 5.5243
# valid auc: 0.1620
# node dim: 64,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 4.0317
# valid auc: 0.8561
# node dim: 64,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 5.0696
# valid auc: 0.8562
# node dim: 64,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 6.5585
# valid auc: 0.1923
# node dim: 64,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 8.0412
# valid auc: 0.4302
# node dim: 64,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 10.2763
# valid auc: 0.7974
# node dim: 64,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 4.8477
# valid auc: 0.8561
# node dim: 64,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 7.1068
# valid auc: 0.8541
# node dim: 64,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 9.7875
# valid auc: 0.1447
# node dim: 64,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 11.3769
# valid auc: 0.7784
# node dim: 64,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 13.8673
# valid auc: 0.8119
# node dim: 64,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 6.5379
# valid auc: 0.8561
# node dim: 64,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.9948
# valid auc: 0.3340
# node dim: 64,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 11.6977
# valid auc: 0.2127
# node dim: 64,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 15.1785
# valid auc: 0.7991
# node dim: 64,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 17.4008
# valid auc: 0.8136
# node dim: 64,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 7.8471
# valid auc: 0.8561
# node dim: 64,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 11.2865
# valid auc: 0.2624
# node dim: 64,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 14.3140
# valid auc: 0.7463
# node dim: 64,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 18.1448
# valid auc: 0.8042
# node dim: 64,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 21.1240
# valid auc: 0.8164
# node dim: 128,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 2.0987
# valid auc: 0.8566
# node dim: 128,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 3.2167
# valid auc: 0.8566
# node dim: 128,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 4.3829
# valid auc: 0.8562
# node dim: 128,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 5.8343
# valid auc: 0.1576
# node dim: 128,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 6.5841
# valid auc: 0.1530
# node dim: 128,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 3.4338
# valid auc: 0.8566
# node dim: 128,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 5.4683
# valid auc: 0.8564
# node dim: 128,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 7.4449
# valid auc: 0.1919
# node dim: 128,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 9.9481
# valid auc: 0.3005
# node dim: 128,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 11.6211
# valid auc: 0.8324
# node dim: 128,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 4.8058
# valid auc: 0.8566
# node dim: 128,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 8.3541
# valid auc: 0.8558
# node dim: 128,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 10.4164
# valid auc: 0.1437
# node dim: 128,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 13.2190
# valid auc: 0.8071
# node dim: 128,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 16.5400
# valid auc: 0.8421
# node dim: 128,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 6.6617
# valid auc: 0.8566
# node dim: 128,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.6690
# valid auc: 0.3311
# node dim: 128,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 14.0440
# valid auc: 0.1652
# node dim: 128,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 16.7822
# valid auc: 0.8280
# node dim: 128,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 21.8368
# valid auc: 0.8452
# node dim: 128,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 7.0774
# valid auc: 0.8566
# node dim: 128,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 12.4128
# valid auc: 0.2571
# node dim: 128,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 16.8277
# valid auc: 0.7382
# node dim: 128,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 20.6691
# valid auc: 0.8333
# node dim: 128,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 26.0157
# valid auc: 0.8465
# node dim: 256,	num_walks: 1,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 1.0000	training time: 2.1628
# valid auc: 0.8562
# node dim: 256,	num_walks: 1,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 2.0000	training time: 3.7104
# valid auc: 0.8562
# node dim: 256,	num_walks: 1,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 3.0000	training time: 5.5690
# valid auc: 0.8563
# node dim: 256,	num_walks: 1,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 4.0000	training time: 7.1695
# valid auc: 0.1612
# node dim: 256,	num_walks: 1,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 72795	average walk length: 5.0000	training time: 9.9033
# valid auc: 0.1492
# node dim: 256,	num_walks: 2,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 1.0000	training time: 3.4512
# valid auc: 0.8562
# node dim: 256,	num_walks: 2,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 2.0000	training time: 6.9927
# valid auc: 0.8567
# node dim: 256,	num_walks: 2,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 3.0000	training time: 9.7069
# valid auc: 0.1917
# node dim: 256,	num_walks: 2,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 4.0000	training time: 13.1361
# valid auc: 0.2362
# node dim: 256,	num_walks: 2,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 145590	average walk length: 5.0000	training time: 17.7461
# valid auc: 0.8343
# node dim: 256,	num_walks: 3,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 1.0000	training time: 5.4481
# valid auc: 0.8562
# node dim: 256,	num_walks: 3,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 2.0000	training time: 9.0256
# valid auc: 0.8568
# node dim: 256,	num_walks: 3,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 3.0000	training time: 13.8560
# valid auc: 0.1436
# node dim: 256,	num_walks: 3,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 4.0000	training time: 18.6399
# valid auc: 0.8042
# node dim: 256,	num_walks: 3,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 218385	average walk length: 5.0000	training time: 25.5591
# valid auc: 0.8459
# node dim: 256,	num_walks: 4,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 1.0000	training time: 6.0051
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 12.2438
# valid auc: 0.3227
# node dim: 256,	num_walks: 4,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 3.0000	training time: 17.9907
# valid auc: 0.1544
# node dim: 256,	num_walks: 4,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 4.0000	training time: 24.4876
# valid auc: 0.8288
# node dim: 256,	num_walks: 4,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 291180	average walk length: 5.0000	training time: 31.6717
# valid auc: 0.8478
# node dim: 256,	num_walks: 5,	walk_length: 1,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 1.0000	training time: 7.9351
# valid auc: 0.8562
# node dim: 256,	num_walks: 5,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 2.0000	training time: 14.0079
# valid auc: 0.2529
# node dim: 256,	num_walks: 5,	walk_length: 3,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 22.8737
# valid auc: 0.5821
# node dim: 256,	num_walks: 5,	walk_length: 4,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 4.0000	training time: 28.8814
# valid auc: 0.8373
# node dim: 256,	num_walks: 5,	walk_length: 5,	p: 2.40,	q: 0.40,	w: 20.00,	e: 20.00	building a node2vec model...	number of walks: 363975	average walk length: 5.0000	training time: 38.5351
# valid auc: 0.8492

# %%
print("max accuracy = ",max(node2vec_auc_scores.values()))
#print(max(node2vec_auc_scores, key=node2vec_auc_scores.get))
res = [key for key in node2vec_auc_scores if node2vec_auc_scores[key] == max(node2vec_auc_scores.values())]
print(res)
# Out:
# max accuracy =  0.8578666075
# [(256, 5, 3, 2.4, 0.4, 20, 5, 'valid')]

# %% [markdown]
# Example of using Heatmap to viualize the result.

# %%
# plt.figure(figsize=(6, 4))
# node_dim = 256
# # TODO: you should have an auc score dictionary here; build by trying difference walk lengths and num_walks
# #a = np.array([[node2vec_auc_scores[(node_dim, num_walks, walk_length,p, q)] for walk_length in [10, 20, 40]] for num_walks in [5, 10, 20, 40]])
# a = np.array([[node2vec_auc_scores[(node_dim, numwalks, walklength,p, q,"valid")] for walklength in walk_length] for numwalks in num_walks])
# #a = np.array(node2vec_auc_scores.values())
# plt.imshow(a, cmap="hot", interpolation="nearest")
# plt.colorbar()
# plt.xticks(ticks=np.arange(len(walk_length)), labels=walk_length)
# plt.xlabel("walk_length")
# plt.yticks(ticks=np.arange(len(num_walks)), labels=num_walks)
# plt.ylabel("num_walks")

# %% [markdown]
# ##Model with the best parameters you find and save the prediction here.

# %%
#print(res[0])
#(node_dim, num_walks, walk_length,p,q, num_window, num_epochs,_) = res[0]
(node_dim, num_walks, walk_length,p,q, num_window, num_epochs,_) = (256, 5, 3, 2.4, 0.2, 20, 5, 'valid')
alias_nodes, alias_edges = preprocess_transition_probs(graph, p, q)
model = build_node2vec(graph, alias_nodes,alias_edges, node_dim, num_walks, walk_length,num_window,num_epochs) # TODO
scores = [get_cosine_sim(model, src, dst) for src, dst in test_edges]
write_pred("data/pred.csv", test_edges, scores)
# Out:
# building a node2vec model...	number of walks: 363975	average walk length: 3.0000	training time: 36.1377

# %%
get_auc_score_test(model, test_edges, test_scores)
# Out:
# 0.7120633725
