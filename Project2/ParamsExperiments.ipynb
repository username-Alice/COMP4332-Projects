# %%
import networkx as nx
import numpy as np
import os
import time
import pandas as pd
import matplotlib.pyplot as plt
from itertools import chain
from collections import defaultdict
from gensim.models import Word2Vec
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### Data Loader

# %% [markdown]
# We need to load networks into memory. Usually networks are organized as pairs of nodes. And sometimes different edges have different weights. Hence, we use networkx.DiGraph to store such structure information and attributes.

# %%
def load_data(file_name):
    """
    read edges from an edge file
    """
    edges = list()
    df = pd.read_csv(file_name)
    for idx, row in df.iterrows():
        user_id, friends = row["user_id"], eval(row["friends"])
        for friend in friends:
            # add each friend relation as an edge
            edges.append((user_id, friend))
    edges = sorted(edges)

    return edges

def load_test_data(file_name):
    """
    read edges from an edge file
    """
    edges = list()
    scores = list()
    df = pd.read_csv(file_name)
    for idx, row in df.iterrows():
        edges.append((row["src"], row["dst"]))
        scores.append(row["score"])
    #edges = sorted(edges)

    return edges,scores

def generate_false_edges(true_edges, num_false_edges=5):
    """
    generate false edges given true edges
    """
    nodes = list(set(chain.from_iterable(true_edges)))
    N = len(nodes)
    true_edges = set(true_edges)
    print(N, len(true_edges))
    false_edges = set()

    while len(false_edges) < num_false_edges:
        # randomly sample two different nodes and check whether the pair exisit or not
        src, dst = nodes[int(np.random.rand() * N)], nodes[int(np.random.rand() * N)]
        if src != dst and (src, dst) not in true_edges and (src, dst) not in false_edges:
            false_edges.add((src, dst))
    false_edges = sorted(false_edges)

    return false_edges

def construct_graph_from_edges(edges):
    """
    generate a directed graph object given true edges
    DiGraph documentation: https://networkx.github.io/documentation/stable/reference/classes/digraph.html
    """
    # convert a list of edges {(u, v)} to a list of edges with weights {(u, v, w)}
    edge_weight = defaultdict(float)
    for e in edges:
        edge_weight[e] += 1.0
    weighed_edge_list = list()
    for e in sorted(edge_weight.keys()):
        weighed_edge_list.append((e[0], e[1], edge_weight[e]))

    graph = nx.DiGraph()
    graph.add_weighted_edges_from(weighed_edge_list)

    print("number of nodes:", graph.number_of_nodes())
    print("number of edges:", graph.number_of_edges())

    return graph

# %% [markdown]
# ### Random Walk Generator

# %% [markdown]
# Random walk generators or random walkers yield random walks that contain both local and higher-order neighborhood information. However, naive non-uniform sampling is very slow, which requires O(n) time complexity. Here alias sampling can reduce the time complexity to O(1) with O(n) space. If you are interested, please see the following blog.

# %%
def alias_setup(probs):
    """
    compute utility lists for non-uniform sampling from discrete distributions.
    details: https://lips.cs.princeton.edu/the-alias-method-efficient-sampling-with-many-discrete-outcomes/
    """
    K = len(probs)
    q = np.zeros(K)
    J = np.zeros(K, dtype=int)

    smaller = list()
    larger = list()
    for kk, prob in enumerate(probs):
        q[kk] = K * prob
        if q[kk] < 1.0:
            smaller.append(kk)
        else:
            larger.append(kk)

    while len(smaller) > 0 and len(larger) > 0:
        small = smaller.pop()
        large = larger.pop()

        J[small] = large
        q[large] = q[large] + q[small] - 1.0
        if q[large] < 1.0:
            smaller.append(large)
        else:
            larger.append(large)

    return J, q

def get_alias_node(graph, node):
    """
    get the alias node setup lists for a given node.
    """
    # get the unnormalized probabilities with the first-order information
    unnormalized_probs = list()
    for nbr in graph.neighbors(node):
        unnormalized_probs.append(graph[node][nbr]["weight"])
    unnormalized_probs = np.array(unnormalized_probs)
    if len(unnormalized_probs) > 0:
        normalized_probs = unnormalized_probs / unnormalized_probs.sum()
    else:
        normalized_probs = unnormalized_probs

    return alias_setup(normalized_probs)

def get_alias_edge(graph, src, dst, p=1, q=1):
    """
    get the alias edge setup lists for a given edge.
    """
    # get the unnormalized probabilities with the second-order information
    unnormalized_probs = list()
    for dst_nbr in graph.neighbors(dst):
        if dst_nbr == src: # distance is 0
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"]/p)
        elif graph.has_edge(dst_nbr, src): # distance is 1
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"])
        else: # distance is 2
            unnormalized_probs.append(graph[dst][dst_nbr]["weight"]/q)
    unnormalized_probs = np.array(unnormalized_probs)
    if len(unnormalized_probs) > 0:
        normalized_probs = unnormalized_probs / unnormalized_probs.sum()
    else:
        normalized_probs = unnormalized_probs

    return alias_setup(normalized_probs)

def preprocess_transition_probs(graph, p=1, q=1):
    """
    preprocess transition probabilities for guiding the random walks.
    """
    alias_nodes = dict()
    for node in graph.nodes():
        alias_nodes[node] = get_alias_node(graph, node)

    alias_edges = dict()
    for edge in graph.edges():
        alias_edges[edge] = get_alias_edge(graph, edge[0], edge[1], p=p, q=q)

    return alias_nodes, alias_edges

# %% [markdown]
# The difference between DeepWalk and node2vec is how to generate random walks. The former only consider the first-order information while the latter also involves the second-order information.

# %%
def alias_draw(J, q):
    """
    draw sample from a non-uniform discrete distribution using alias sampling.
    """
    K = len(J)

    kk = int(np.floor(np.random.rand() * K))
    if np.random.rand() < q[kk]:
        return kk
    else:
        return J[kk]


# helper function to generate the long random walk as desired
def fallback(walk, fetch_last_num=1):
    if len(walk) > fetch_last_num:
        walk.pop()
        fetched = []
        for i in range(fetch_last_num):
            fetched.append(walk[-1-i])
        return walk, fetched
    else:
        return [], [None for _ in range(fetch_last_num)]

def generate_first_order_random_walk(graph, alias_nodes,
                                     walk_length=10, start_node=None, verbose=False, max_trails=10):
    """
    simulate a random walk starting from start node and considering the first order information.
    max_trials: set the max trials to be one for standard random walk. Larger max_trails will make the generated biased.
    """
    if start_node == None:
        start_node = np.random.choice(graph.nodes())
    walk = [start_node]
    cur = start_node
    num_tried = 0

    ########## begin ##########
    while len(walk) < walk_length:
        cur_nbrs = list(graph.neighbors(cur))
        if len(cur_nbrs) > 0: # if we can sample next nodes
            # sample the next node based on alias_nodes
            cur = cur_nbrs[alias_draw(*alias_nodes[cur])]
            walk.append(cur)
        else: # if we can't do that
            num_tried += 1
            if num_tried >= max_trails:
                break

            walk, fetched = fallback(walk, fetch_last_num=1)
            cur = fetched[0]
            if len(walk) == 0: # if falls back to the empty walk
                start_node = np.random.choice(graph.nodes())
                walk = [start_node]
                cur = start_node
    ########## end ##########

    if verbose:
        print(f'walk of lenght {len(walk)} generated with {num_tried} trails')
    return walk

def generate_second_order_random_walk(graph, alias_nodes, alias_edges,
                                      walk_length=10, start_node=None, verbose=False, max_trails=10):
    """
    simulate a random walk starting from start node and considering the second order information.
    """
    if start_node == None:
        start_node = np.random.choice(graph.nodes())
    walk = [start_node]

    prev = None
    cur = start_node
    num_tried = 0

    ########## begin ##########
    while len(walk) < walk_length:
        cur_nbrs = list(graph.neighbors(cur))
        if len(cur_nbrs) > 0:
            if prev is None:
                # sample the next node based on alias_nodes
                prev, cur = cur, cur_nbrs[alias_draw(*alias_nodes[cur])]
            else:
                # sample the next node based on alias_edges
                prev, cur = cur, cur_nbrs[alias_draw(*alias_edges[(prev, cur)])]
            walk.append(cur)
        else:
            num_tried += 1
            if num_tried >= max_trails:
                break
            walk, (cur, prev) = fallback(walk, fetch_last_num=2)
            if len(walk) == 0:
                start_node = np.random.choice(graph.nodes())
                walk = [start_node]
                cur = start_node
                prev = None
    ########## end ##########
    if verbose:
        print(f'walk of lenght {len(walk)} generated with {num_tried} trails')
    return walk

# %% [markdown]
# ### Network Embedding Algorithms

# %%
def build_deepwalk(graph, alias_nodes, node_dim=10, num_walks=10, walk_length=10):
    """
    build a deepwalk model
    """
    print("building a DeepWalk model...", end="\t")
    st = time.time()
    np.random.seed(0)
    nodes = list(graph.nodes())
    walks = list()
    # generate random walks
    for walk_iter in range(num_walks):
        np.random.shuffle(nodes)
        for node in nodes:
            walks.append(generate_first_order_random_walk(
                graph, alias_nodes, walk_length=walk_length, start_node=node))

    walk_lens = [len(w) for w in walks]
    if len(walk_lens) > 0:
        avg_walk_len = sum(walk_lens) / len(walk_lens)
    else:
        avg_walk_len = 0.0
    print("number of walks: %d\taverage walk length: %.4f" % (len(walks), avg_walk_len), end="\t")

    # train a skip-gram model for these walks
    model = Word2Vec(walks, vector_size=node_dim, window=3, min_count=0, sg=1, workers=os.cpu_count(), epochs=10)
    print("training time: %.4f" % (time.time()-st))

    return model

def build_node2vec(graph, alias_nodes, alias_edges, node_dim=10, num_walks=10, walk_length=10,num_window = 3, num_epoch = 10):
    """
    build a node2vec model
    """
    print("building a node2vec model...", end="\t")
    st = time.time()
    np.random.seed(0)
    nodes = list(graph.nodes())
    walks = list()
    # generate random walks
    for walk_iter in range(num_walks):
        np.random.shuffle(nodes)
        for node in nodes:
            walks.append(generate_second_order_random_walk(
                graph, alias_nodes, alias_edges, walk_length=walk_length, start_node=node))

    walk_lens = [len(w) for w in walks]
    if len(walk_lens) > 0:
        avg_walk_len = sum(walk_lens) / len(walk_lens)
    else:
        avg_walk_len = 0.0
    print("number of walks: %d\taverage walk length: %.4f" % (len(walks), avg_walk_len), end="\t")

    # train a skip-gram model for these walks
    model = Word2Vec(walks, vector_size=node_dim, window=num_window, min_count=0, sg=1, workers=os.cpu_count(), epochs=num_epoch)
    print("training time: %.4f" % (time.time()-st))

    return model

# %% [markdown]
# ### Scorer

# %%
def get_cosine_sim(model, u, v):
    """
    get the cosine similarity between two nodes
    """
    try:
        u = model.wv[u]
        v = model.wv[v]
        return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))
    except:
        return 0.5

def get_auc_score(model, true_edges, false_edges):
    """
    get the auc score
    """
    y_true = [1] * len(true_edges) + [0] * len(false_edges)

    y_score = list()
    for e in true_edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))
    for e in false_edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))

    return roc_auc_score(y_true, y_score)

def get_auc_score_test(model, edges,scores):
    """
    get the auc score
    """
    y_true = scores

    y_score = list()
    for e in edges:
        y_score.append(get_cosine_sim(model, e[0], e[1]))

    return roc_auc_score(y_true, y_score)


def write_pred(file_name, edges, scores):
    df = pd.DataFrame()
    df["src"] = [e[0] for e in edges]
    df["dst"] = [e[1] for e in edges]
    df["score"] = scores
    df.to_csv(file_name, index=False)





def write_valid_ans(file_name, edges, scores):
    df = pd.DataFrame()
    df["src"] = [e[0] for e in edges]
    df["dst"] = [e[1] for e in edges]
    df["score"] = scores
    df.to_csv(file_name, index=False)

# %% [markdown]
# ### Try them over a Real-life Network

# %% [markdown]
# Firstly, we need to load edges into memory and use the networkx.DiGraph structure to store the graph.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# data_path = "/content/drive/MyDrive/Colab Notebooks/comp4332/Project2/data"
# !rm -f data
# !ln -s "/content/drive/MyDrive/Colab Notebooks/comp4332/Project2/data" data
# Out:
# Mounted at /content/drive

# %%
train_file = "data/train.csv"
valid_file = "data/valid.csv"
test_file = "data/test.csv"

np.random.seed(2024)
train_edges = load_data(train_file)
graph = construct_graph_from_edges(train_edges)
#nx.draw(graph)
valid_edges = load_data(valid_file)
false_edges = generate_false_edges(train_edges + valid_edges, 40000 - len(valid_edges))
test_edges,test_scores = load_test_data(test_file)
# Out:
# number of nodes: 72795
# number of edges: 100000
# 85407 120000

# %% [markdown]
# After that, we can use preprocess transition probabilities with the help of alias sampling.

# %%
#alias_nodes, alias_edges = preprocess_transition_probs(graph, p=1, q=1)

# %% [markdown]
# We can use random walk generators to generate random walks.

# %% [markdown]
# Let's try to generate a first-order random walk and a second-order random walk.

# %%
#generate_first_order_random_walk(graph, alias_nodes=alias_nodes,
#                                 start_node="B01I2MU2JQ", walk_length=10)

# %%
#generate_second_order_random_walk(graph, alias_nodes=alias_nodes, alias_edges=alias_edges,
#                                  start_node="B01I2MU2JQ", walk_length=10)

# %% [markdown]
# And we can build a DeepWalk model and a node2vec model. Here we set p=q=0.5 so that the walker will not go very far away from the start node.

# %%
#model_walk = build_deepwalk(graph, alias_nodes, node_dim=20, num_walks=10, walk_length=10)

# %%
#model_work2vec = build_node2vec(graph, alias_nodes, alias_edges, node_dim=20, num_walks=10, walk_length=10)

# %%
#model = model_walk

# %% [markdown]
# Let's see the node embeddings of three nodes, and cosine similarities of two edges.

# %%
'''print("node embedding (\"AF7QSFSONY6JAFLVH3PFOLFQWETA\"):",
      model.wv["AF7QSFSONY6JAFLVH3PFOLFQWETA"])
print("node embedding (\"B01I2MU2JQ\"):",
      model.wv["B01I2MU2JQ"])
print("node embedding (\"AFKMKEPHZWDWJXRRR36T5RC7625Q\"):",
      model.wv.vectors[model.wv.index_to_key.index("AFKMKEPHZWDWJXRRR36T5RC7625Q")])
print("true edge (\"AF7QSFSONY6JAFLVH3PFOLFQWETA\", \"B01I2MU2JQ\"):",
      get_cosine_sim(model, "AF7QSFSONY6JAFLVH3PFOLFQWETA", "B01I2MU2JQ"))
print("false edge (\"AF7QSFSONY6JAFLVH3PFOLFQWETA\", \"AFKMKEPHZWDWJXRRR36T5RC7625Q\"):",
      get_cosine_sim(model, "N6ZTMIue-2b30CJv2tyPGg", "MmlJSLDg-IFaeXb5wdJbgg"))'''
# Out:
# 'print("node embedding ("AF7QSFSONY6JAFLVH3PFOLFQWETA"):",\n      model.wv["AF7QSFSONY6JAFLVH3PFOLFQWETA"])\nprint("node embedding ("B01I2MU2JQ"):",\n      model.wv["B01I2MU2JQ"])\nprint("node embedding ("AFKMKEPHZWDWJXRRR36T5RC7625Q"):",\n      model.wv.vectors[model.wv.index_to_key.index("AFKMKEPHZWDWJXRRR36T5RC7625Q")])\nprint("true edge ("AF7QSFSONY6JAFLVH3PFOLFQWETA", "B01I2MU2JQ"):",\n      get_cosine_sim(model, "AF7QSFSONY6JAFLVH3PFOLFQWETA", "B01I2MU2JQ"))\nprint("false edge ("AF7QSFSONY6JAFLVH3PFOLFQWETA", "AFKMKEPHZWDWJXRRR36T5RC7625Q"):",\n      get_cosine_sim(model, "N6ZTMIue-2b30CJv2tyPGg", "MmlJSLDg-IFaeXb5wdJbgg"))'

# %% [markdown]
# # Link Prediction

# %% [markdown]
# We can train the model with different parameters and test the model on the validation set. Please show your parameter search process and analysis in your code, and visualization tools (Heatmap, etc.) are recommended to make your analysis clear.

# %%
# np.random.seed(0)

# node_dim = np.array([64,128,256,512]) # only 64 is finished, when node_dim = 128, numwalk , walk length = 25, accuracy = 75.19
# num_walks = np.arange(25,101,25)
# walk_length = np.arange(25,101,25)
# best_dim = -1
# best_walk = -1
# best_length = -1
# best_score = -1
# deepwalk_auc_scores = dict()
# """print("node dim: %d,\tnum_walks: %d,\twalk_length: %d" % (node_dim, num_walks, walk_length), end="\t")"""
# for dim in node_dim:
#   for walk in num_walks:
#     for length in walk_length:
#       model = build_deepwalk(graph, alias_nodes,
#               node_dim = dim, num_walks= walk, walk_length = length)
#       deepwalk_auc_scores[(dim, walk, length,'valid')] = get_auc_score(model, valid_edges, false_edges)
#       print("valid auc: %.4f" % (deepwalk_auc_scores[(dim, walk, length,'valid')]))

# %%
node_dim = np.array([256])
num_walks = [4]#np.arange(2,17,2)
walk_length = [2]#np.arange(2,17,2)
num_window = [3]#np.arange(10,51,10)
num_epochs = [10]#np.arange(10,51,10)
P = np.arange(0.2,4.2,0.2)
Q = np.arange(0.2,4.2,0.2)

# %%
np.random.seed(0)
node2vec_auc_scores = dict()
for numWindow in num_window:
    for numEpoch in num_epochs:
        for dim in node_dim:
            for walk in num_walks:
                for length in walk_length:
                    for p in P:
                        for q in Q:
                            print("node dim: %d,\tnum_walks: %d,\twalk_length: %d,\tp: %.2f,\tq: %.2f,\tw: %.2f,\te: %.2f" % (
                                dim, walk, length, p, q,numWindow,numEpoch), end="\t")
                            alias_nodes, alias_edges = preprocess_transition_probs(graph, p=p, q=q)
                            model = build_node2vec(graph, alias_nodes, alias_edges,
                                                    node_dim=dim, num_walks=walk, walk_length=length,num_window=numWindow,num_epoch=numEpoch)
                            node2vec_auc_scores[(dim, walk, length, p, q,numWindow,numEpoch,'valid')] = get_auc_score(model, valid_edges, false_edges)
                            print("valid auc: %.4f" % (node2vec_auc_scores[(dim, walk, length, p, q,numWindow,numEpoch,'valid')]))
# Out:
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.7360
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7591
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.7128
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.9270
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 12.1870
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 14.3330
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5409
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6260
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8272
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9993
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7751
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9763
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0464
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0164
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.6617
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7191
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8942
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9923
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6080
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.20,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8252
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6510
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6911
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7721
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4729
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.4064
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3286
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5259
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4829
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5890
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7741
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5940
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0824
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5069
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.0870
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5349
# valid auc: 0.8563
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5599
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7211
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7491
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5910
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.40,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7131
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9233
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8712
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.9961
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5880
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8292
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8952
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9063
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.4457
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8622
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9813
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2316
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5840
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.0480
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3216
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5629
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5239
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6690
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8092
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6470
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.60,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1505
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5980
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.2652
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4849
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6190
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7871
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8682
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5900
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6520
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7551
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6370
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7761
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1612
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9273
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8932
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6240
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3757
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5669
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7291
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7201
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 0.80,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6280
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1895
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.6136
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9973
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4969
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7761
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6730
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8482
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0234
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9073
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0984
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.7137
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5639
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8962
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1174
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5049
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5990
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6370
# valid auc: 0.8563
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7011
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1725
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.00,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.2163
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8772
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4729
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0314
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.8791
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5389
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6130
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5489
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9533
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1955
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.2543
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.7000
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5179
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7491
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6350
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3276
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5619
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.6559
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5529
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.9362
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.20,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1682
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0063
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1235
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0954
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0634
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.5538
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.7931
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2926
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7801
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.6006
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.6559
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3827
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0134
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2244
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6110
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9993
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5399
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.8081
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.9012
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.7718
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.40,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.1603
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5339
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7321
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9353
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.8391
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7871
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.6278
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9313
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 14.3410
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6861
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9723
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.9122
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.5947
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5629
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2806
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.8581
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.6628
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 16.8443
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9133
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7881
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.60,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.3966
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.9389
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5689
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 12.7465
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4819
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.8181
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8042
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 13.5863
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.5845
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5539
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 13.2380
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9903
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5159
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.2785
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.4036
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2724
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 17.7020
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7761
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 12.4953
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.5294
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 1.80,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5910
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6500
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8322
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8872
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4989
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6090
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.3063
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7011
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8522
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5579
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6570
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8922
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7511
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8112
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3447
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5820
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.9440
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6270
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9413
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7541
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.00,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9903
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8022
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1805
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6280
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5479
# valid auc: 0.8563
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.3013
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9313
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6730
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0224
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9193
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8562
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2446
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5359
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6340
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.3274
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0063
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5489
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5910
# valid auc: 0.8563
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6060
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9373
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.20,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.4367
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5369
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7071
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7221
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1502
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8642
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.4688
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5529
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.4839
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7241
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8782
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7391
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2846
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.2683
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.3667
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5329
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5139
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 2.40,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7031
# valid auc: 0.8562
# ...
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2015
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.7519
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5679
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2304
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6370
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8002
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.5055
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.1454
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1405
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.7920
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5359
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2874
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1585
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6380
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.4507
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6881
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 13.1189
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9373
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.40,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.7379
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9383
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.7860
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2264
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5910
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.1144
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.7040
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 13.8736
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5569
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.6589
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2774
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1542
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.5178
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.5606
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6020
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.5547
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.8420
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 13.2390
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1842
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.3684
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.60,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.8998
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6100
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.9312
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0984
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.3624
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6821
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 11.8097
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 12.6545
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 13.2920
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.4907
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6600
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 8.2705
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.2305
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1242
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.3184
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.5647
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 18.0614
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 9.2854
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 12.8657
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.0111
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 3.80,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5930
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 0.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6290
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 0.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7911
# valid auc: 0.8561
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 0.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6861
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 0.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6520
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 1.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.2966
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 1.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7011
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 1.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6730
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 1.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8122
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 1.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9203
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 2.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6530
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 2.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.7591
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 2.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8052
# valid auc: 0.8563
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 2.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.8572
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 2.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6560
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 3.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 10.1432
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 3.20,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.5629
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 3.40,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.9603
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 3.60,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 7.0924
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 3.80,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6460
# valid auc: 0.8562
# node dim: 256,	num_walks: 4,	walk_length: 2,	p: 4.00,	q: 4.00,	w: 3.00,	e: 10.00	building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 6.6230
# valid auc: 0.8562

# %%
print("max accuracy = ",max(node2vec_auc_scores.values()))
#print(max(node2vec_auc_scores, key=node2vec_auc_scores.get))
res = [key for key in node2vec_auc_scores if node2vec_auc_scores[key] == max(node2vec_auc_scores.values())]
print(res)

# %% [markdown]
# Example of using Heatmap to viualize the result.

# %%
plt.figure(figsize=(8, 6))
node_dim = 256
# TODO: you should have an auc score dictionary here; build by trying difference walk lengths and num_walks
#a = np.array([[node2vec_auc_scores[(node_dim, num_walks, walk_length,p, q)] for walk_length in [10, 20, 40]] for num_walks in [5, 10, 20, 40]])
a = np.array([[node2vec_auc_scores[(node_dim, 4, 2,p, q,3,10,"valid")] for p in P] for q in Q])
formatted_P = ["{:.1f}".format(num) for num in P]
formatted_Q = ["{:.1f}".format(num) for num in Q]
#a = np.array(node2vec_auc_scores.values())
plt.imshow(a, cmap="hot", interpolation="nearest")
plt.colorbar()
plt.xticks(ticks=np.arange(len(P)), labels=formatted_P)
plt.xlabel("P")
plt.yticks(ticks=np.arange(len(Q)), labels=formatted_Q)
plt.ylabel("Q")
# Out:
# Text(0, 0.5, 'Q')

# %% [markdown]
# ##Model with the best parameters you find and save the prediction here.

# %%
#print(res[0])

#(node_dim, num_walks, walk_length,p,q, num_window, num_epochs,_) = res[0]
(node_dim, num_walks, walk_length,p,q, num_window, num_epochs,_) = (256, 4, 2,2.4,0.2, 3, 10,"valid")
alias_nodes, alias_edges = preprocess_transition_probs(graph, p, q)
model = build_node2vec(graph, alias_nodes,alias_edges, node_dim, num_walks, walk_length,num_window,num_epochs) # TODO
scores = [get_cosine_sim(model, src, dst) for src, dst in test_edges]
write_pred("data/pred.csv", test_edges, scores)
# Out:
# building a node2vec model...	number of walks: 291180	average walk length: 2.0000	training time: 29.2385

# %%
get_auc_score_test(model, test_edges, test_scores)
# Out:
# 0.7113633475000001
